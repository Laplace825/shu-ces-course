# %% [markdown]
# # Problem 4.
# Using a multilayer perceptron with Keras produce a GEOMETRIC FORM with the dimension of your election.
#
# **Remark**: In other words, use the equation of ANY GEOMETRIC FORM (except the TORUS), then generate artificial data to generate X, Y and Z. Then you use data of X, Y Z to train a Neural Network, and then form the shape of the selected form but produced by the Neural Network. In your report you should mention the equation of the geometric form you selected, and the figures generated by the equation and by your neural network.

# %%
# how many points to generate
points = 20000


def generate_data(points):
    # generate random data in an uniform distribution
    return phi, theta, x, y, z


data = generate_data(points)

# stack the data into a matrix
X = np.vstack((data[0], data[1])).T
Y = np.vstack((data[2:])).T

# %% [markdown]
# ## split the data and train the model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

model = Sequential(
)

model.compile(optimizer=, loss=)
history = model.fit(X_train, Y_train, epochs=50, verbose=1)

# %%
model.summary()

# %% [markdown]
# ## use the model to predict the test set

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# ## draw the original sphere and the predicted sphere

# %%
fig = plt.figure(figsize=(12, 6))

# the original sphere
ax1 = fig.add_subplot(121, projection="3d")
ax1.scatter(Y_test[:, 0], Y_test[:, 1], Y_test[:, 2], c="b")
ax1.set_title("Original Sphere")

# the predicted sphere
ax2 = fig.add_subplot(122, projection="3d")
ax2.scatter(Y_pred[:, 0], Y_pred[:, 1], Y_pred[:, 2], c="r")
ax2.set_title("Predicted Sphere")

plt.show()

# %% [markdown]
# # draw the loss history

# %%
plt.plot(history.)
